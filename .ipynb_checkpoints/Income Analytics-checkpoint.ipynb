# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def scatter_text(x, y, color_column, text_column, data, title, xlabel, ylabel):
    """Scatter plot with country codes on the x y coordinates
       Based on this answer: https://stackoverflow.com/a/54789170/2641825"""
    # Create the scatter plot
    p1 = sns.scatterplot(x, y, color_column, data=data, size = 8, legend=False)
    # Add text besides each point
    for line in range(0,data.shape[0]):
         p1.text(data[x][line]+0.01, data[y][line], 
                 data[text_column][line], horizontalalignment='left', 
                 size='medium', color='black', weight='semibold')
    # Set title and axis labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    return p1

# %%
df=pd.read_csv('IncomeData.csv', delimiter=';')
df
# Out:
#           Nom            Prenom       Ecole  Diplome    Emploi   Fixe  \
# 0   AMAHZOUNE             Ranya  Universite     2018  Confirme  49000
# 1      CHEIKH            Chaima       ENSAI     2017  Confirme  49000
# 2   DE LASSUS          Athanase   Ingenieur     2018  Confirme  50000
# 3        DIOP             Fatou       ENSAI     2018  Confirme  49000
# 4      DUCLOS          Frederic   Ingenieur     2010    Senior  58500
# 5      DUFILS            Martin   Ingenieur     2013    Senior  56000
# 6      GUERIN          Timothee  Universite     2015    Senior  56000
# 7          HA    Thi Phuong Anh        ISFA     2015    Senior  57000
# 8       JIANG            Yinjia  Universite     2016    Junior  45000
# 9          LI           Mengzhu       ENSAI     2016  Confirme  51000
# 10      NAHAS              Rita   Ingenieur     2015  Confirme  56000
# 11      PETIT  SophieCCharlotte    Commerce     2017  Confirme  46000
# ...

# %%
sns.scatterplot(x=df['Diplome'],y=df["Remuneration"],hue=df['Ecole'])

# %%
plt.figure(figsize=(20,10))
scatter_text('Diplome', 'Remuneration', 'Ecole','Nom',
             data = df_iris, 
             title = 'Iris sepals', 
             xlabel = 'Sepal Length (cm)',
             ylabel = 'Sepal Width (cm)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a6103c71e1d9> in <module>()
#       1 plt.figure(figsize=(20,10))
# ----> 2 scatter_text('Diplome', 'Remuneration', 'Ecole','Nom',
#       3              data = df_iris,
#       4              title = 'Iris sepals',
#       5              xlabel = 'Sepal Length (cm)',
#
# NameError: name 'scatter_text' is not defined
